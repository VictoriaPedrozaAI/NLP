# %% [markdown]
# <a href="https://colab.research.google.com/github/VictoriaPedrozaAI/NLP/blob/main/Sentiment_Classification__IMDb_V4Epochs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import imdb
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Embedding, LSTM, GRU, Dense
import time
import matplotlib.pyplot as plt

# Load dataset
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=5000)
x_train = pad_sequences(x_train, maxlen=200)
x_test = pad_sequences(x_test, maxlen=200)

# LSTM Model
model_lstm = Sequential([
    Embedding(5000, 128),
    LSTM(128),
    Dense(1, activation='sigmoid')
])
model_lstm.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

start = time.time()
history_lstm = model_lstm.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=4, batch_size=64)
print("LSTM training time:", time.time() - start)

# Plot accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history_lstm.history['accuracy'], label='LSTM Train Acc')
plt.plot(history_lstm.history['val_accuracy'], label='LSTM Val Acc')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history_lstm.history['loss'], label='LSTM Train Loss')
plt.plot(history_lstm.history['val_loss'], label='LSTM Val Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/4
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.6836 - loss: 0.5639 - val_accuracy: 0.8545 - val_loss: 0.3503
# Epoch 2/4
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.8836 - loss: 0.2876 - val_accuracy: 0.8715 - val_loss: 0.3018
# Epoch 3/4
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9153 - loss: 0.2137 - val_accuracy: 0.8639 - val_loss: 0.3319
# Epoch 4/4
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.9410 - loss: 0.1625 - val_accuracy: 0.8678 - val_loss: 0.3281
# LSTM training time: 40.52685880661011

# %%
from keras.datasets import imdb
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Embedding, GRU, Dense
import time
import matplotlib.pyplot as plt

# Load dataset
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=5000)
x_train = pad_sequences(x_train, maxlen=200)
x_test = pad_sequences(x_test, maxlen=200)

# GRU Model
model_gru = Sequential([
    Embedding(5000, 128),
    GRU(128),
    Dense(1, activation='sigmoid')
])
model_gru.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

start = time.time()
history_gru = model_gru.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=4, batch_size=64)
print("GRU training time:", time.time() - start)

# Plot accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history_gru.history['accuracy'], label='GRU Train Acc')
plt.plot(history_gru.history['val_accuracy'], label='GRU Val Acc')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history_gru.history['loss'], label='GRU Train Loss')
plt.plot(history_gru.history['val_loss'], label='GRU Val Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/4
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.6635 - loss: 0.5826 - val_accuracy: 0.8448 - val_loss: 0.3553
# Epoch 2/4
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8818 - loss: 0.2915 - val_accuracy: 0.8740 - val_loss: 0.3084
# Epoch 3/4
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.9196 - loss: 0.2042 - val_accuracy: 0.8856 - val_loss: 0.2937
# Epoch 4/4
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9491 - loss: 0.1420 - val_accuracy: 0.8769 - val_loss: 0.3489
# GRU training time: 32.22215390205383
