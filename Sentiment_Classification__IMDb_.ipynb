# %% [markdown]
# <a href="https://colab.research.google.com/github/VictoriaPedrozaAI/NLP/blob/main/Sentiment_Classification__IMDb_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import imdb
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Embedding, LSTM, GRU, Dense
import time
import matplotlib.pyplot as plt

# Load dataset
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=5000)
x_train = pad_sequences(x_train, maxlen=200)
x_test = pad_sequences(x_test, maxlen=200)

# LSTM Model
model_lstm = Sequential([
    Embedding(5000, 128),
    LSTM(128),
    Dense(1, activation='sigmoid')
])
model_lstm.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

start = time.time()
history_lstm = model_lstm.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=2, batch_size=64)
print("LSTM training time:", time.time() - start)

# Plot accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history_lstm.history['accuracy'], label='LSTM Train Acc')
plt.plot(history_lstm.history['val_accuracy'], label='LSTM Val Acc')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history_lstm.history['loss'], label='LSTM Train Loss')
plt.plot(history_lstm.history['val_loss'], label='LSTM Val Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/2
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 261s 659ms/step - accuracy: 0.7204 - loss: 0.5288 - val_accuracy: 0.7758 - val_loss: 0.4703
# Epoch 2/2
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 263s 662ms/step - accuracy: 0.8662 - loss: 0.3160 - val_accuracy: 0.8674 - val_loss: 0.3087
# LSTM training time: 523.6379187107086

# %%
from keras.datasets import imdb
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Embedding, GRU, Dense
import time
import matplotlib.pyplot as plt

# Load dataset
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=5000)
x_train = pad_sequences(x_train, maxlen=200)
x_test = pad_sequences(x_test, maxlen=200)

# GRU Model
model_gru = Sequential([
    Embedding(5000, 128),
    GRU(128),
    Dense(1, activation='sigmoid')
])
model_gru.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

start = time.time()
history_gru = model_gru.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=2, batch_size=64)
print("GRU training time:", time.time() - start)

# Plot accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history_gru.history['accuracy'], label='GRU Train Acc')
plt.plot(history_gru.history['val_accuracy'], label='GRU Val Acc')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history_gru.history['loss'], label='GRU Train Loss')
plt.plot(history_gru.history['val_loss'], label='GRU Val Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/2
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 281s 713ms/step - accuracy: 0.7038 - loss: 0.5394 - val_accuracy: 0.8523 - val_loss: 0.3934
# Epoch 2/2
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 322s 712ms/step - accuracy: 0.8767 - loss: 0.3107 - val_accuracy: 0.8653 - val_loss: 0.3204
# GRU training time: 603.3193778991699
